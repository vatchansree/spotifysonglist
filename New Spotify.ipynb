# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('spotify_dataset.csv')

# %%
df1 = df

# %%
df1.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# ...

# %%
df1.shape
# Out:
# (1556, 23)

# %%
df1.iloc[0:10]
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
# 5      6                          1                       18
# 6      7                          3                       16
# 7      8                          2                       10
# 8      9                          3                        8
# 9     10                          8                       10
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# ...

# %%
df1.columns
# Out:
# Index(['Index', 'Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord'],
#       dtype='object')

# %%
df1.describe()
# Out:
#              Index  Highest Charting Position  Number of Times Charted
# count  1556.000000                1556.000000              1556.000000
# mean    778.500000                  87.744216                10.668380
# std     449.322824                  58.147225                16.360546
# min       1.000000                   1.000000                 1.000000
# 25%     389.750000                  37.000000                 1.000000
# 50%     778.500000                  80.000000                 4.000000
# 75%    1167.250000                 137.000000                12.000000
# max    1556.000000                 200.000000               142.000000

# %%
df1['Song ID'].dropna().value_counts().head(10)
# Out:
#                           11
# 5uEYRdEIh9Bo4fpjDd4Na9     3
# 4S2uhQE8L9V6p7rj7SiauJ     2
# 35UUpTmrcFXNIVIN26ujXl     2
# 2YpeDb67231RjR0MgVLzsG     2
# 4lUmnwRybYH7mMzf16xB0y     2
# 0oQc0F6KUE7QY7k5TU6bic     2
# 7wsmIIm0xWmtP7TmACXkJn     2
# 1iQDltZqI7BXnHrFy4Qo1k     2
# 1D3z6HTiQsNmZxjl7F7eoG     2
# Name: Song ID, dtype: int64

# %%
df1[df1['Song ID'] == ' ']
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 35       36                         36                        1
# 163     164                          5                       39
# 464     465                        118                        1
# 530     531                         20                        5
# 636     637                         22                        6
# 654     655                         73                        1
# 750     751                         19                       20
# 784     785                         76                       14
# 876     877                        164                        4
# 1140   1141                        131                        1
# 1538   1539                        176                        1
#
#      Week of Highest Charting  \
# 35     2021-07-23--2021-07-30
# 163    2020-10-30--2020-11-06
# 464    2021-03-26--2021-04-02
# 530    2021-01-15--2021-01-22
# 636    2020-12-18--2020-12-25
# ...

# %%
song_names = df1['Song Name'][df1['Song ID'] == ' ']
art_name = df1['Artist'][df1['Song ID'] == ' ']
for i, y  in zip(song_names, art_name):
    print(f'Song', i)
    print(f'____','by', y, 'haven\'t ID')
# Out:
# Song NOT SOBER (feat. Polo G & Stunna Gambino)
# ____ by The Kid LAROI haven't ID
# Song 34+35
# ____ by Ariana Grande haven't ID
# Song Richer (feat. Polo G)
# ____ by Rod Wave haven't ID
# Song 34+35 Remix (feat. Doja Cat, Megan Thee Stallion) - Remix
# ____ by Ariana Grande haven't ID
# Song Driving Home for Christmas - 2019 Remaster
# ____ by Chris Rea haven't ID
# Song Thank God It's Christmas - Non-Album Single
# ____ by Queen haven't ID
# Song Agua (with J Balvin) - Music From "Sponge On The Run" Movie
# ____ by Tainy haven't ID
# Song Lean (feat. Towy, Osquel, Beltito & Sammy & Falsetto)
# ____ by Super Yei, Jone Quest haven't ID
# Song +Linda
# ____ by Dalex haven't ID
# Song In meinem Benz
# ____ by AK AUSSERKONTROLLE, Bonez MC haven't ID
# Song fuck, i'm lonely (with Anne-Marie) - from “13 Reasons Why: Season 3”
# ____ by Lauv haven't ID

# %%
df1[df1['Artist'] == 'Queen'].sort_values(by=['Song Name'])
# Out:
#      Index  Highest Charting Position  Number of Times Charted  \
# 178    179                        138                       22
# 141    142                         81                       81
# 612    613                        138                       13
# 654    655                         73                        1
#
#     Week of Highest Charting                                     Song Name  \
# 178   2021-04-02--2021-04-09  Another One Bites The Dust - Remastered 2011
# 141   2019-12-27--2020-01-03           Bohemian Rhapsody - Remastered 2011
# 612   2019-12-27--2020-01-03           Don't Stop Me Now - Remastered 2011
# 654   2020-12-18--2020-12-25   Thank God It's Christmas - Non-Album Single
#
#         Streams Artist Artist Followers                 Song ID  \
# 178   5,204,983  Queen         35888760  57JVGBtBLCfHw2muk5416J
# 141   5,756,583  Queen         35888760  7tFiyTwD0nx5a1eklYtX2J
# 612   4,630,572  Queen         35910149  7hQJA50XrCWABAu5v6QZ4i
# ...

# %%
df1[df1['Artist'] == 'Dalex'].sort_values(by=['Song Name'])
# Out:
#      Index  Highest Charting Position  Number of Times Charted  \
# 876    877                        164                        4
#
#     Week of Highest Charting Song Name    Streams Artist Artist Followers  \
# 876   2020-09-18--2020-09-25    +Linda  4,964,708  Dalex
#
#     Song ID Genre  ... Danceability Energy Loudness Speechiness Acousticness  \
# 876                ...
#
#     Liveness Tempo Duration (ms) Valence Chord
# 876
#
# [1 rows x 23 columns]

# %%
df1[['Week of Highest Charting_start','Week of Highest Charting_end']] = df1['Week of Highest Charting'].str.split('--', expand=True)

# %%
cols = list(df.columns.values)

# %%
cols = ['Highest Charting Position',
 'Number of Times Charted',
 'Week of Highest Charting',
 'Week of Highest Charting_start',
 'Week of Highest Charting_end',
 'Song Name',
 'Streams',
 'Artist',
 'Artist Followers',
 'Song ID',
 'Genre',
 'Release Date',
 'Weeks Charted',
 'Popularity',
 'Danceability',
 'Energy',
 'Loudness',
 'Speechiness',
 'Acousticness',
 'Liveness',
 'Tempo',
 'Duration (ms)',
 'Valence',
 'Chord']

# %%
dff = df1[cols]

# %%
dff.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# ...

# %%
dff['Week of Highest Charting_start'] = pd.to_datetime(dff['Week of Highest Charting_start'], yearfirst=True)
dff['Week of Highest Charting_end'] = pd.to_datetime(dff['Week of Highest Charting_end'], yearfirst=True)
dff['Streams'] = dff['Streams'].replace(',','', regex=True)
dff['Streams'] = dff['Streams'].astype('int32')
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Highest Charting Position       1556 non-null   int64
#  1   Number of Times Charted         1556 non-null   int64
#  2   Week of Highest Charting        1556 non-null   object
#  3   Week of Highest Charting_start  1556 non-null   datetime64[ns]
#  4   Week of Highest Charting_end    1556 non-null   datetime64[ns]
#  5   Song Name                       1556 non-null   object
#  6   Streams                         1556 non-null   int32
#  7   Artist                          1556 non-null   object
#  8   Artist Followers                1556 non-null   object
#  9   Song ID                         1556 non-null   object
#  10  Genre                           1556 non-null   object
#  11  Release Date                    1556 non-null   object
# ...

# %%
duplicated_ID = df1['Song ID'].dropna().value_counts().head(29)
duplicated_ID = duplicated_ID[1:29]
print(f'Duplicated Songs ID:','\n', duplicated_ID)
duplicated_ID = pd.DataFrame(duplicated_ID)
duplicated_ID.reset_index(drop=False, inplace=True)
print(type(duplicated_ID))
# Out:
# Duplicated Songs ID:
#  5uEYRdEIh9Bo4fpjDd4Na9    3
# 4S2uhQE8L9V6p7rj7SiauJ    2
# 35UUpTmrcFXNIVIN26ujXl    2
# 2YpeDb67231RjR0MgVLzsG    2
# 4lUmnwRybYH7mMzf16xB0y    2
# 0oQc0F6KUE7QY7k5TU6bic    2
# 7wsmIIm0xWmtP7TmACXkJn    2
# 1iQDltZqI7BXnHrFy4Qo1k    2
# 1D3z6HTiQsNmZxjl7F7eoG    2
# 2MbdDtCv5LUVjYy9RuGTgC    2
# 0GzuHFG4Ql6DoyxFRnIk3F    2
# 1SV1fxF65n9NhRHp3KlBuu    2
# 37BZB0z9T8Xu7U3e65qxFy    2
# 4umIPjkehX1r7uhmGvXiSV    2
# 3yZCjDTxzZxx1kll1sRjGc    2
# 0t3ZvGKlmYmVsDzBJAXK8C    2
# 7ygpwy2qP3NbrxVkHvUhXY    2
# 1WedZeiezCmCEOzLwhx0hV    2
# 463CkQjx2Zk1yXoBuierM9    2
# 02kDW379Yfd5PzW5A6vuGt    2
# 73O30uMI7n6DuzBmbtO7kC    2
# 0e6NlGJxYlHvAN8SKxad7N    2
# 5VwwpU7KsLhgfbMEecedhJ    2
# 6uvMKqNlrSvcC4NaKnrwjZ    2
# 4ZRrLHqzhGRXYj2qcB4s5S    2
# 27RSJHEA99Y0Vsow7nA37A    2
# 2AlYncTpVHKwHb55F9lF6O    2
# 07Oz5StQ7GRoygNLaXs2pd    2
# Name: Song ID, dtype: int64
# <class 'pandas.core.frame.DataFrame'>

# %%
ddf= pd.DataFrame()
for i in duplicated_ID['index']:
    j = pd.DataFrame(dff[dff['Song ID'] == i])
    ddf = ddf.append(j)
print(dff.shape)
# Out:
# (1556, 25)

# %%
print(r'before dropping duplicates:',(ddf.count()[0]), 'raws')
print(r'after dropping duplicates:',(ddf.drop_duplicates(['Song ID'])).count()[0], 'raws')
# Out:
# before dropping duplicates: 57 raws
# after dropping duplicates: 28 raws

# %%
dff = dff.loc[dff['Song ID'] != ' ']
dff.drop_duplicates('Song ID', inplace=True)
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1516 entries, 0 to 1555
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Index                           1516 non-null   int64
#  1   Highest Charting Position       1516 non-null   int64
#  2   Number of Times Charted         1516 non-null   int64
#  3   Week of Highest Charting        1516 non-null   object
#  4   Song Name                       1516 non-null   object
#  5   Streams                         1516 non-null   object
#  6   Artist                          1516 non-null   object
#  7   Artist Followers                1516 non-null   object
#  8   Song ID                         1516 non-null   object
#  9   Genre                           1516 non-null   object
#  10  Release Date                    1516 non-null   object
#  11  Weeks Charted                   1516 non-null   object
# ...

# %%
plt.plot(dff.Streams, dff.Danceability, 's-b')
plt.plot(dff.Streams, dff.Energy, 'o--r')

plt.xlabel('No. of times streamed')
plt.ylabel('Value for Danceability/Energy');

plt.title("Danceability & Energy relation")
plt.legend(['Danceability', 'Energy']);

# %%
sns.scatterplot(x=dff.Streams, 
                y=dff.Valence, 
                s=100);

plt.xlabel('No. of times streamed')
plt.ylabel('Valence(musical positiveness conveyed)');
plt.title("Streams v/s Valence");

# %%
plt.hist(dff["Duration (ms)"]);

plt.xlabel("Duration of song(ms)")
plt.ylabel("No. of songs")
plt.title("Distribution of Duration of songs");

# %%
artists_top200_count = dff['Artist'].value_counts()

# %%
artists_top200_count
# Out:
# Taylor Swift                     52
# Lil Uzi Vert                     32
# Justin Bieber                    32
# Juice WRLD                       30
# Pop Smoke                        29
#                                  ..
# Nicky Jam, Myke Towers            1
# Hugo & Guilherme                  1
# Jason Derulo, Nuka                1
# Zoe Wees                          1
# Dadá Boladão, Tati Zaqui, OIK     1
# Name: Artist, Length: 702, dtype: int64

# %%
sns.scatterplot(x=dff.Streams, y=dff.Popularity, s=50)

plt.xlabel('No. of times streamed')
plt.ylabel('Popularity Ranking');

# %%
df1 = dff

# %%
df1.drop(['Week of Highest Charting','Song Name','Release Date','Weeks Charted','Week of Highest Charting_end'], axis=1, inplace=True)
df1[['Artist','Chord']] = df1[['Artist','Chord']].astype('category')
df1['Streams'] = df1['Streams'].replace(',','', regex=True)
df1['Streams'] = df1['Streams'].astype('int16')
df1['Artist Followers'] = df1['Artist Followers'].astype('int16')

# %%
df1[['Danceability','Energy','Loudness','Speechiness','Acousticness','Liveness','Tempo','Valence']] = df1[['Danceability','Energy','Loudness','Speechiness','Acousticness','Liveness','Tempo','Valence']].astype('float16')
df1['Popularity'] = df1['Popularity'].astype('int16')
df1['Duration (ms)'] = df1['Duration (ms)'].astype('int16')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1516 entries, 0 to 1555
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Index                           1516 non-null   int64
#  1   Highest Charting Position       1516 non-null   int64
#  2   Number of Times Charted         1516 non-null   int64
#  3   Streams                         1516 non-null   int16
#  4   Artist                          1516 non-null   category
#  5   Artist Followers                1516 non-null   int16
#  6   Song ID                         1516 non-null   object
#  7   Genre                           1516 non-null   object
#  8   Popularity                      1516 non-null   int16
#  9   Danceability                    1516 non-null   float16
#  10  Energy                          1516 non-null   float16
#  11  Loudness                        1516 non-null   float16
# ...

# %%
df2 = df1

# %%
df2.drop(['Artist','Genre', 'Song ID'], axis=1, inplace=True)

# %%
df2.describe()
# Out:
#              Index  Highest Charting Position  Number of Times Charted  \
# count  1516.000000                1516.000000              1516.000000
# mean    778.759235                  88.295515                10.627968
# std     449.256761                  58.233646                16.373370
# min       1.000000                   1.000000                 1.000000
# 25%     389.750000                  38.000000                 1.000000
# 50%     779.500000                  81.500000                 4.000000
# 75%    1168.250000                 138.000000                12.000000
# max    1556.000000                 200.000000               142.000000
#
#             Streams  Artist Followers   Popularity  Danceability       Energy  \
# count   1516.000000       1516.000000  1516.000000   1516.000000  1516.000000
# mean    -457.308047       2481.075198    69.955805      0.689453     0.633301
# std    18967.471858      19395.201972    15.889346      0.141968     0.161865
# ...

# %%
s = (df2.dtypes == 'category')
category = list(s[s].index)

print("Categorical variables:", category)
# Out:
# Categorical variables: []

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
notes = df2['Chord']
enc_df = pd.DataFrame(enc.fit_transform(df2[['Chord']]).toarray())
enc_df.columns = enc.get_feature_names(['Chord'])
df2 = df2.join(enc_df)
df2.drop(['Chord'], axis=1, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1516 entries, 0 to 1555
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Index                           1516 non-null   int64
#  1   Highest Charting Position       1516 non-null   int64
#  2   Number of Times Charted         1516 non-null   int64
#  3   Streams                         1516 non-null   int16
#  4   Artist Followers                1516 non-null   int16
#  5   Popularity                      1516 non-null   int16
#  6   Danceability                    1516 non-null   float16
#  7   Energy                          1516 non-null   float16
#  8   Loudness                        1516 non-null   float16
#  9   Speechiness                     1516 non-null   float16
#  10  Acousticness                    1516 non-null   float16
#  11  Liveness                        1516 non-null   float16
# ...

# %%
df3 = df2

# %%
y = df3['Popularity']
X = df3.drop(['Popularity'], axis=1)
print('Full dataset shape is:',df3.shape)
print('Feature dataset shape is:',X.shape)
print('Target dataset shape is:',y.shape)
# Out:
# Full dataset shape is: (1516, 28)
# Feature dataset shape is: (1516, 27)
# Target dataset shape is: (1516,)

# %%
#eli5

! pip install eli5 --user

# %%
#eli5

! pip install eli5 --user

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
y = df3['Popularity']
X = df3.drop(['Popularity'], axis=1)
print('Full dataset shape is:',df3.shape)
print('Feature dataset shape is:',X.shape)
print('Target dataset shape is:',y.shape)
# Out:
# Full dataset shape is: (1516, 28)
# Feature dataset shape is: (1516, 27)
# Target dataset shape is: (1516,)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

data = df3
feature_names = [i for i in X.columns if data[i].dtype in [np.int64]]
X = data[feature_names]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
my_model = RandomForestClassifier(n_estimators=100,
                                  random_state=0).fit(train_X, train_y)

# %%
import eli5
from eli5.sklearn import PermutationImportance

# %%
perm = PermutationImportance(my_model, random_state=1).fit(val_X, val_y)
eli5.show_weights(perm, feature_names = val_X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0697
#
#                     &plusmn; 0.0136
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Index
#             </td>
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=13)

params = {'n_estimators': 100,
          'max_depth': 4,
          'min_samples_split': 5,
          'learning_rate': 0.01,
          'loss': 'squared_error'}

# %%
reg = ensemble.GradientBoostingRegressor()
reg.fit(X_train, y_train)

mse = mean_squared_error(y_test, reg.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 273.1106

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

data = df3
feature_names = [i for i in X.columns if data[i].dtype in [np.int64]]
X = data[feature_names]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
my_model = RandomForestClassifier(n_estimators=100,
                                  random_state=0).fit(train_X, train_y)
feature_importance = reg.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(X.columns)[sorted_idx])
plt.title('Feature Importance (MDI)')

result = permutation_importance(reg, X_test, y_test, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()
plt.subplot(1, 2, 2)
plt.boxplot(result.importances[sorted_idx].T,
            vert=False, labels=np.array(X.columns)[sorted_idx])
plt.title("Permutation Importance (test set)")
fig.tight_layout()
plt.show()
